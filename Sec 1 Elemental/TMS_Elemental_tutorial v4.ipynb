# %% [markdown]
# # **TMS 2025 AI Workshop: Ryan Jacobs, Ben Afflerbach, Dane Morgan (UW-Madison)**
#
# ![Screenshot 2025-09-04 at 3.45.50 PM.png](data:image/png;base64,...)
#
# ---
#
#
# ## Google Colab notebook for fitting elemental properties:
# ## example of conditional generation of high voltage Na-battery materials

# %% [markdown]
# # Installation and setup
#
# To begin, we need to install or import a few needed python packages.

# %%
# Installs
# The following gives and error and asks to restart the session. Just do that and rerun.
# Materials specific packages (this takes a few minutes first time, about 1 min after restart).
#!pip install pymatgen mp_api             # A useful package for working with materials data.
#!pip install mastml==3.2.4                        # Materials related ML package
#!pip install numpy==1.26.4
# !pip install mastml
# Out:
# Collecting mastml
#   Downloading mastml-3.2.5-py3-none-any.whl.metadata (984 bytes)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from mastml) (1.6.1)
# Collecting scikit-optimize (from mastml)
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting matminer (from mastml)
#   Downloading matminer-0.9.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mastml) (3.10.0)
# Collecting mdf-forge (from mastml)
#   Downloading mdf_forge-0.8.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting mdf-toolbox (from mastml)
#   Downloading mdf_toolbox-0.7.1-py2.py3-none-any.whl.metadata (821 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mastml) (2.0.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from mastml) (3.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from mastml) (2.2.2)
# Collecting pathos (from mastml)
#   Downloading pathos-0.3.4-py3-none-any.whl.metadata (11 kB)
# Collecting pykan==0.0.5 (from mastml)
#   Downloading pykan-0.0.5-py3-none-any.whl.metadata (13 kB)
# Collecting pymatgen (from mastml)
#   Downloading pymatgen-2025.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mastml) (6.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mastml) (1.16.2)
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (from mastml) (0.48.0)
# Collecting sphinx-automodapi (from mastml)
#   Downloading sphinx_automodapi-0.20.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sphinx-rtd-theme (from mastml)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from mastml) (0.14.5)
# Collecting madml (from mastml)
#   Downloading madml-2.6.7-py3-none-any.whl.metadata (2.5 kB)
# Collecting udocker (from mastml)
#   Downloading udocker-1.3.17-py2.py3-none-any.whl.metadata (37 kB)
# Collecting transfernet (from mastml)
#   Downloading transfernet-0.4.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting forestci (from mastml)
#   Downloading forestci-0.7.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mastml) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mastml) (3.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from madml->mastml) (4.67.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from madml->mastml) (8.4.2)
# Collecting docker (from madml->mastml)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from madml->mastml) (2.19.0)
# Collecting scikeras (from madml->mastml)
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting kneed (from madml->mastml)
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: requests~=2.31 in /usr/local/lib/python3.12/dist-packages (from matminer->mastml) (2.32.4)
# Collecting pymongo~=4.5 (from matminer->mastml)
#   Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: sympy~=1.11 in /usr/local/lib/python3.12/dist-packages (from matminer->mastml) (1.13.3)
# Collecting monty>=2023 (from matminer->mastml)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->mastml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->mastml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->mastml) (2025.2)
# Collecting bibtexparser>=1.4.0 (from pymatgen->mastml)
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from pymatgen->mastml) (3.5)
# Requirement already satisfied: orjson<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from pymatgen->mastml) (3.11.3)
# Collecting palettable>=3.3.3 (from pymatgen->mastml)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen->mastml) (5.24.1)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen->mastml)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Collecting spglib>=2.5 (from pymatgen->mastml)
#   Downloading spglib-2.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen->mastml) (0.9.0)
# Collecting uncertainties>=3.1.4 (from pymatgen->mastml)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mastml) (3.2.5)
# Collecting globus-sdk>=1.7.0 (from mdf-forge->mastml)
#   Downloading globus_sdk-4.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting fair-research-login>=0.2.4 (from mdf-toolbox->mastml)
#   Downloading fair_research_login-0.3.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: jsonschema>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from mdf-toolbox->mastml) (4.25.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->mastml) (2.0.0)
# Collecting ppft>=1.7.7 (from pathos->mastml)
#   Downloading ppft-1.7.7-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.4.0 (from pathos->mastml)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.6 (from pathos->mastml)
#   Downloading pox-0.3.6-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.18 (from pathos->mastml)
#   Downloading multiprocess-0.70.18-py312-none-any.whl.metadata (7.5 kB)
# Collecting pyaml>=16.9 (from scikit-optimize->mastml)
#   Downloading pyaml-25.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap->mastml) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap->mastml) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap->mastml) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap->mastml) (4.15.0)
# Requirement already satisfied: sphinx>=4 in /usr/local/lib/python3.12/dist-packages (from sphinx-automodapi->mastml) (8.2.3)
# Requirement already satisfied: docutils<0.22,>0.18 in /usr/local/lib/python3.12/dist-packages (from sphinx-rtd-theme->mastml) (0.21.2)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->mastml)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->mastml) (1.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from transfernet->mastml) (2.8.0+cu126)
# Collecting globus-sdk>=1.7.0 (from mdf-forge->mastml)
#   Downloading globus_sdk-3.65.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pyjwt<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]<3.0.0,>=2.0.0->globus-sdk>=1.7.0->mdf-forge->mastml) (2.10.1)
# Requirement already satisfied: cryptography!=3.4.0,>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from globus-sdk>=1.7.0->mdf-forge->mastml) (43.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.3.0->mdf-toolbox->mastml) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.3.0->mdf-toolbox->mastml) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.3.0->mdf-toolbox->mastml) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.3.0->mdf-toolbox->mastml) (0.27.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap->mastml) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->pymatgen->mastml) (8.5.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.5->matminer->mastml)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->mastml) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.31->matminer->mastml) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.31->matminer->mastml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.31->matminer->mastml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.31->matminer->mastml) (2025.10.5)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen->mastml)
#   Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4->sphinx-automodapi->mastml) (3.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy~=1.11->matminer->mastml) (1.3.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->madml->mastml) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->madml->mastml) (1.6.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras->madml->mastml) (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (2.19.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->madml->mastml) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (3.20.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->transfernet->mastml) (3.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->madml->mastml) (0.45.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography!=3.4.0,>=3.3.1->globus-sdk>=1.7.0->mdf-forge->mastml) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=4->sphinx-automodapi->mastml) (3.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras->madml->mastml) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras->madml->mastml) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras->madml->mastml) (0.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->madml->mastml) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->madml->mastml) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->madml->mastml) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography!=3.4.0,>=3.3.1->globus-sdk>=1.7.0->mdf-forge->mastml) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras->madml->mastml) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras->madml->mastml) (0.1.2)
# Downloading mastml-3.2.5-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.5 MB/s eta 0:00:00
# Downloading pykan-0.0.5-py3-none-any.whl (33 kB)
# Downloading madml-2.6.7-py3-none-any.whl (18.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 64.6 MB/s eta 0:00:00
# Downloading matminer-0.9.3-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 106.6 MB/s eta 0:00:00
# Downloading pymatgen-2025.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 92.8 MB/s eta 0:00:00
# Downloading mdf_forge-0.8.0-py2.py3-none-any.whl (17 kB)
# Downloading mdf_toolbox-0.7.1-py2.py3-none-any.whl (35 kB)
# Downloading pathos-0.3.4-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 5.8 MB/s eta 0:00:00
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 7.1 MB/s eta 0:00:00
# Downloading sphinx_automodapi-0.20.0-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 7.9 MB/s eta 0:00:00
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 104.7 MB/s eta 0:00:00
# Downloading transfernet-0.4.2-py3-none-any.whl (8.5 kB)
# Downloading udocker-1.3.17-py2.py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.6/119.6 kB 8.8 MB/s eta 0:00:00
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 7.6 MB/s eta 0:00:00
# Downloading fair_research_login-0.3.1-py3-none-any.whl (39 kB)
# Downloading globus_sdk-3.65.0-py3-none-any.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.0/418.0 kB 17.8 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.18-py312-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 9.4 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 19.9 MB/s eta 0:00:00
# Downloading pox-0.3.6-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.7-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.7 MB/s eta 0:00:00
# Downloading pyaml-25.7.0-py3-none-any.whl (26 kB)
# Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 64.6 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.15-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 8.2 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 40.3 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 7.0 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 3.5 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 8.4 MB/s eta 0:00:00
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 17.5 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.1/753.1 kB 35.9 MB/s eta 0:00:00
# Building wheels for collected packages: forestci, bibtexparser
#   Building wheel for forestci (setup.py) ... done
#   Created wheel for forestci: filename=forestci-0.7-py3-none-any.whl size=12016 sha256=fad88d3cd38f2abbbe9d880672b6d5cf0e4434dc14826ac869470481a9103edc
#   Stored in directory: /root/.cache/pip/wheels/7c/d7/8c/a908960c682518809fa805687f32c9f24f0ab29c22a233b5e1
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=3a10e54d7eaa0d3e72ceb2a6e2a78b91ad66c44a1df63f22310c5beec50be6b6
#   Stored in directory: /root/.cache/pip/wheels/1f/7d/e9/1ff2509f13767a55df1279744adfb757f4ab94b2cbe761f56a
# Successfully built forestci bibtexparser
# Installing collected packages: udocker, uncertainties, spglib, ruamel.yaml.clib, pykan, pyaml, ppft, pox, palettable, dnspython, dill, bibtexparser, ruamel.yaml, pymongo, multiprocess, kneed, docker, sphinxcontrib-jquery, sphinx-automodapi, scikit-optimize, pathos, monty, forestci, sphinx-rtd-theme, scikeras, pymatgen, globus-sdk, transfernet, matminer, madml, fair-research-login, mdf-toolbox, mdf-forge, mastml
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.16
#     Uninstalling multiprocess-0.70.16:
#       Successfully uninstalled multiprocess-0.70.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# datasets 4.0.0 requires multiprocess<0.70.17, but you have multiprocess 0.70.18 which is incompatible.
# Successfully installed bibtexparser-1.4.3 dill-0.4.0 dnspython-2.8.0 docker-7.1.0 fair-research-login-0.3.1 forestci-0.7 globus-sdk-3.65.0 kneed-0.8.5 madml-2.6.7 mastml-3.2.5 matminer-0.9.3 mdf-forge-0.8.0 mdf-toolbox-0.7.1 monty-2025.3.3 multiprocess-0.70.18 palettable-3.3.3 pathos-0.3.4 pox-0.3.6 ppft-1.7.7 pyaml-25.7.0 pykan-0.0.5 pymatgen-2025.10.7 pymongo-4.15.3 ruamel.yaml-0.18.15 ruamel.yaml.clib-0.2.14 scikeras-0.13.0 scikit-optimize-0.10.2 spglib-2.6.0 sphinx-automodapi-0.20.0 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1 transfernet-0.4.2 udocker-1.3.17 uncertainties-3.2.3

# %%
# Imports (This takes about 1 min). Has a few errors and warnings but it seems we can ignore those.
from mastml.mastml import Mastml
from mastml.datasets import LocalDatasets
from mastml.data_cleaning import DataCleaning
from mastml.preprocessing import SklearnPreprocessor
from mastml.models import SklearnModel
from mastml.data_splitters import SklearnDataSplitter, NoSplit
from mastml.mastml_predictor import make_prediction
from mastml.feature_selectors import EnsembleModelFeatureSelector, NoSelect, SklearnFeatureSelector, MASTMLFeatureSelector
from mastml.feature_selectors import ShapFeatureSelector
from mastml.feature_generators import ElementalFeatureGenerator
from mastml.learning_curve import LearningCurve
from mastml.hyper_opt import GridSearch
from mastml.hyper_opt import GridSearch

# Python utilities packages
#!pip install pandas
import os                        # OS stands for Operating System and provides ways for python to interact with files or directories
from collections import Counter  # Collections is a package for handling data
from pprint import pprint

import pandas as pd              # Pandas is a data analysis library which we'll primarily use to handle our dataset
import numpy as np               # Numpy is a package for scientific computing. We'll use it for some of it's math functions
import pymatgen                  # Pymatgen is a library for materials analysis which we use to interpret our material compositions
from pymatgen import core as pymatgen_core       # Needed to get core to be accessible.  Note sure why. 9/5/23.

import matplotlib                # Matplotlib is the plotting package that we'll use throughout the lab
import matplotlib.pyplot as plt
import seaborn as sns            # Seaborn is a Python data visualization library based on matplotlib
# Out:
# Figshare is an optional dependency. To import data from figshare, manually install figshare via git clone of git clone https://github.com/cognoma/figshare.git
# ERROR:duecredit:Failed to import duecredit due to No module named 'duecredit'
# scikit-lego is an optional dependency, enabling use of the LowessRegression model. If you want to use this model, do "pip install scikit-lego"
# linear-tree is an optional dependency, enabling use of Linear tree, forest, and boosting models. If you want to use this model, do "pip install linear-tree"
# gplearn is an optional dependency, enabling the use of genetic programming SymbolicRegressor model. If you want to use this model, do "pip install gplearn"
# sklearn-extra is an optional dependency, used to do LeaveOutClusterCV. To use it, do pip install sklearn_extra
# CBFV is an optional dependency. To install CBFV, do pip install cbfv
# DeepChem is an optional dependency used to generate molecular descriptors from RDKit. To install Deepchem, do pip install deepchem

# %% [markdown]
# # Obtaining the data used for fitting

# %% [markdown]
# There is a saved data file in the Google Drive which contains the calculated
# average voltage of Na insertion. The data were obtained by screening materials
# from the Materials Project and calculting the voltage using a Universal
# Machine Learning Interatomic Potential (U-MLIP)

# %% [markdown]
# This cell links your Google drive to the Colab session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Set up path to directory with input files and where output will be sent. Checks that the path name is assigned correctly.

# %%
#d = '/content/drive/MyDrive/Online Filed/Dane Morgan Mixed Sharing/Projects/TMS AI4MSE for DEMO 2025-10-28/Sec 1 Elemental'
d = '/content/drive/MyDrive/TMS_2025_AI_workshop/'
# !echo $d
os.path.isdir(d)
# Out:
# /content/drive/MyDrive/TMS_2025_AI_workshop/
# True

# %% [markdown]
# Load datafile

# %%
import joblib
df = joblib.load(os.path.join(d, 'mp_Na_eqV2.pkl'))
df.head()
# Out:
#    index                            Relaxed structure, full  \
# 0      0  {'@module': 'pymatgen.core.structure', '@class...
# 1      0  {'@module': 'pymatgen.core.structure', '@class...
# 2      0  {'@module': 'pymatgen.core.structure', '@class...
# 3      0  {'@module': 'pymatgen.core.structure', '@class...
# 4      0  {'@module': 'pymatgen.core.structure', '@class...
#
#                             Relaxed structure, empty  \
# 0  {'@module': 'pymatgen.core.structure', '@class...
# 1  {'@module': 'pymatgen.core.structure', '@class...
# 2  {'@module': 'pymatgen.core.structure', '@class...
# 3  {'@module': 'pymatgen.core.structure', '@class...
# 4  {'@module': 'pymatgen.core.structure', '@class...
#
#                               Relaxed structure, ref  Relaxed energy, full  \
# 0  {'@module': 'pymatgen.core.structure', '@class...            -47.144470
# 1  {'@module': 'pymatgen.core.structure', '@class...           -347.147003
# 2  {'@module': 'pymatgen.core.structure', '@class...           -360.532379
# 3  {'@module': 'pymatgen.core.structure', '@class...           -351.932495
# 4  {'@module': 'pymatgen.core.structure', '@class...            -93.682617
#
#    Relaxed energy, empty  Relaxed energy, ref  Relaxed volume, full  \
# 0             -42.739342            -2.612235             86.925992
# 1            -342.174774            -2.612235            580.632428
# 2            -342.138519            -2.612235            592.342169
# 3            -342.103943            -2.612235            585.379022
# 4             -84.215996            -2.612235            162.257705
#
#    Relaxed volume, empty  Average voltage (V/ion)             mp_id  \
# 0              82.302897                 3.099011  mp-1002571-GGA+U
# 1             580.309435                 3.666111  mp-1003635-GGA+U
# 2             578.011476                 3.292347  mp-1003636-GGA+U
# 3             583.089731                 3.608158  mp-1003638-GGA+U
# 4             136.842690                 3.427193  mp-1003766-GGA+U
#
#   Composition                                          Structure
# 0     NaMn2O4  [[ 1.4537295 -0.858677   2.8019015] Na, [0. 0....
# 1   NaMn16O32  [[4.97042764 4.96925164 4.40963713] Na, [6.467...
# 2     NaMn4O8  [[3.75601408 7.43825464 1.65457529] Na, [ 5.16...
# 3    NaMn8O16  [[-4.9288659   5.00872719 -1.47329048] Na, [-9...
# 4     NaMn2O4  [[1.46205272 2.17082951 8.89991039] Na, [1.462...

# %% [markdown]
# The data file contains U-MLIP relaxed structures and average voltages for 2288 materials. Let's plot a histogram of the computed average voltages to see their distribution:

# %%
def plot_voltage_histogram(df, dataset='MP', ion='Na'):
    bins = np.arange(0, 10, 0.2)

    # Matterverse avg voltage has a bunch of negative values- remove them!
    df = df[df['Average voltage (V/ion)'] >=0]

    plt.clf()

    plt.hist(bins=bins, x=df['Average voltage (V/ion)'], color='red', edgecolor='black', alpha=0.5, label='EquiformerV2')

    plt.xlabel('Average voltage (V/Na)', fontsize=14)
    plt.xticks(fontsize=12)
    plt.ylabel('Number of occurrences', fontsize=14)
    plt.yticks(fontsize=12)
    plt.legend(loc='best')
    plt.savefig('Voltage_histogram_'+dataset+'_'+ion+'.png', dpi=300, bbox_inches='tight')

    vals = df['Average voltage (V/ion)']
    print('EquiformerV2 voltage stats')
    fmt = lambda x: np.format_float_positional(x, precision=3, unique=False, fractional=False, trim='k')

    print(f"{'Mean:':25s}{fmt(np.mean(vals)):>12s}")
    print(f"{'Standard deviation:':25s}{fmt(np.std(vals)):>12s}")
    print(f"{'Min:':25s}{fmt(min(vals)):>12s}")
    print(f"{'Max:':25s}{fmt(max(vals)):>12s}")

    return

# %%
plot_voltage_histogram(df)
# Out:
# EquiformerV2 voltage stats
# Mean:                            4.13
# Standard deviation:             0.916
# Min:                            0.524
# Max:                             6.92

# %% [markdown]
# As we can see, the average voltage is around 4.1 V/Na, with numerous instances of high voltage materials.
#
# Since we only need composition as features and voltage as targets, we next pull out those columns as X and y.

# %%
# Create X and y as DataFrames
X = df[['Composition']].copy()
y = df[['Average voltage (V/ion)']].copy()

# Display combined view
display(pd.concat([X, y], axis=1))
# Out:
#       Composition  Average voltage (V/ion)
# 0         NaMn2O4                 3.099011
# 1       NaMn16O32                 3.666111
# 2         NaMn4O8                 3.292347
# 3        NaMn8O16                 3.608158
# 4         NaMn2O4                 3.427193
# ...           ...                      ...
# 2283      Na2NbF6                 4.609173
# 2284  KNaMo(OF2)2                 5.198510
# 2285   Na3Mn2SbO6                 2.778885
# 2286       NaCuO2                 4.159726
# 2287   Na8Ta7VO24                 4.134991
#
# [2288 rows x 2 columns]

# %% [markdown]
# # Generate features

# %% [markdown]
# Now we generate features with MAST-ML

# %%
# X: DataFrame with a 'composition' column of formula strings
# e.g., X = pd.DataFrame({'composition': ['Fe2O3', 'Al2O3', 'NiTi']})

# Build generator from the compositions in X

composition_df=X[['Composition']]

efg = ElementalFeatureGenerator(
    composition_df,   # pass only the composition column
    feature_types=['composition_avg', 'max' , 'min', 'difference'],    # use available elemental features
    remove_constant_columns=True
)

# Generate elemental features
X_elem, ytemp = efg.evaluate(X=X, y=None, savepath=d, make_new_dir=True)                # returns a DataFrame of features

display(X_elem)
# Out:
# Featurizing compositions:: 2288it [00:01, 1231.86it/s]
# Dropping 4/352 generated columns due to missing values
#       Composition  AtomicNumber_composition_average  AtomicNumber_difference  \
# 0         NaMn2O4                         13.285714                     17.0
# 1       NaMn16O32                         13.612245                     17.0
# 2         NaMn4O8                         13.461538                     17.0
# 3        NaMn8O16                         13.560000                     17.0
# 4         NaMn2O4                         13.285714                     17.0
# ...           ...                               ...                      ...
# 2283      Na2NbF6                         13.000000                     32.0
# 2284  KNaMo(OF2)2                         13.777778                     34.0
# 2285   Na3Mn2SbO6                         15.166667                     43.0
# 2286       NaCuO2                         14.000000                     21.0
# 2287   Na8Ta7VO24                         20.350000                     65.0
#
#       AtomicNumber_max_value  AtomicNumber_min_value  \
# 0                       25.0                     8.0
# 1                       25.0                     8.0
# 2                       25.0                     8.0
# 3                       25.0                     8.0
# 4                       25.0                     8.0
# ...                      ...                     ...
# 2283                    41.0                     9.0
# 2284                    42.0                     8.0
# 2285                    51.0                     8.0
# 2286                    29.0                     8.0
# 2287                    73.0                     8.0
#
#       AtomicRadii_composition_average  AtomicRadii_difference  \
# 0                            1.042857                    1.17
# 1                            0.920408                    1.17
# 2                            0.976923                    1.17
# 3                            0.940000                    1.17
# 4                            1.042857                    1.17
# ...                               ...                     ...
# 2283                         1.061000                    1.18
# 2284                         1.105778                    1.63
# 2285                         1.179167                    1.17
# 2286                         1.159500                    1.17
# 2287                         1.101275                    1.17
#
#       AtomicRadii_max_value  AtomicRadii_min_value  \
# 0                      1.90                   0.73
# 1                      1.90                   0.73
# 2                      1.90                   0.73
# 3                      1.90                   0.73
# 4                      1.90                   0.73
# ...                     ...                    ...
# 2283                   1.90                   0.72
# 2284                   2.35                   0.72
# 2285                   1.90                   0.73
# 2286                   1.90                   0.73
# 2287                   1.90                   0.73
#
#       AtomicVolume_composition_average  ...  n_ws^third_max_value  \
# 0                         10633.236058  ...                  1.61
# 1                         12146.635733  ...                  1.61
# 2                         11448.143575  ...                  1.61
# 3                         11904.491785  ...                  1.61
# 4                         10633.236058  ...                  1.61
# ...                                ...  ...                   ...
# 2283                      12411.836688  ...                  1.64
# 2284                      12413.512853  ...                  1.77
# 2285                       9310.509568  ...                  1.61
# 2286                       9308.915651  ...                  1.47
# 2287                      11166.710266  ...                  1.64
#
#       n_ws^third_min_value  phi_composition_average  phi_difference  \
# 0                     0.82                 1.657143            1.75
# 1                     0.82                 1.508163            1.75
# 2                     0.82                 1.576923            1.75
# 3                     0.82                 1.532000            1.75
# 4                     0.82                 1.657143            1.75
# ...                    ...                      ...             ...
# 2283                  0.82                 1.050000            1.35
# 2284                  0.65                 1.066667            2.40
# 2285                  0.82                 1.783333            1.75
# 2286                  0.82                 1.787500            1.75
# 2287                  0.82                 1.355000            1.55
#
#       phi_max_value  phi_min_value  valence_composition_average  \
# 0              4.45           2.70                     3.285714
# 1              4.45           2.70                     3.612245
# 2              4.45           2.70                     3.461538
# 3              4.45           2.70                     3.560000
# 4              4.45           2.70                     3.285714
# ...             ...            ...                          ...
# 2283           4.05           2.70                     1.444444
# 2284           4.65           2.25                     1.777778
# 2285           4.45           2.70                     2.833333
# 2286           4.45           2.70                     1.750000
# 2287           4.25           2.70                     2.400000
#
#       valence_difference  valence_max_value  valence_min_value
# 0                    6.0                7.0                1.0
# 1                    6.0                7.0                1.0
# 2                    6.0                7.0                1.0
# 3                    6.0                7.0                1.0
# 4                    6.0                7.0                1.0
# ...                  ...                ...                ...
# 2283                 4.0                5.0                1.0
# 2284                 5.0                6.0                1.0
# 2285                 6.0                7.0                1.0
# 2286                 1.0                2.0                1.0
# 2287                 4.0                5.0                1.0
#
# [2288 rows x 349 columns]

# %% [markdown]
# # Fit model

# %% [markdown]
# This section fits the elemental features with Regression using either a Ridge (a kind of regularized linear model) or Random Forest (a powerful tree based model) model. We also have to option to perform feature reduction by taking just a subset of principle components. The code does an 80/20 train/test split and 5-fold Cross-Validation (CV), which are standard ways to test the data.

# %% [markdown]
# Start by loading some relevant ML tools (scikit-learn, a widely used ML package) and setting up global variables to control the fit (choice of PCA and model type).

# %%
print("Starting workflow with optional PCA feature reduction...\n")

# Core sklearn imports
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge  # <-- added for optional linear model

# ======= PCA options =======
USE_PCA = True            # <- turn PCA on/off (True or False)
PCA_VAR_KEEP = 0.95       # keep 95% variance (sklearn PCA allows float in (0,1])
# ===========================

# ======= Model option =======
MODEL_TYPE = "ridge"         # one of: "rf", "ridge"
# ===========================
# Out:
# Starting workflow with optional PCA feature reduction...

# %% [markdown]
# Now we pull out the X and y features and target wiht right format, cleaning out any data that are not numbers.

# %%
# 1) Prepare data (assumes X_elem dataframe, y array-like)
print("[1/7] Preparing data...")
X = X_elem.copy()
y = df['Average voltage (V/ion)'].values.ravel()  # ensure 1D target

# Keep only numeric columns and drop rows with NaNs/Infs
X = X.select_dtypes(include=np.number)
mask = np.isfinite(X).all(axis=1) & np.isfinite(y)
X, y = X.loc[mask], y[mask]

print(f"   -> Data after cleaning: {X.shape[0]} samples, {X.shape[1]} features")
print("   -> Example feature cols:", list(X.columns[:5]), "\n")
# Out:
# [1/7] Preparing data...
#    -> Data after cleaning: 2288 samples, 348 features
#    -> Example feature cols: ['AtomicNumber_composition_average', 'AtomicNumber_difference', 'AtomicNumber_max_value', 'AtomicNumber_min_value', 'AtomicRadii_composition_average']

# %% [markdown]
# Build the model pipeline (including choosing the model). This pipeline tells the code the steps needed in the fitting (scaling, PCA, model fit) so we can run them easily and apply them to train and test data.

# %%
# 2) Build the modeling pipeline: [Scaler] -> [PCA?] -> [Model]
model_name = "RF" if MODEL_TYPE == "rf" else "Ridge"
print("[2/7] Building pipeline (Scaler -> {} -> {})...".format("PCA" if USE_PCA else "No PCA", model_name))
steps = [("scaler", StandardScaler())]
if USE_PCA:
    steps.append(("pca", PCA(n_components=PCA_VAR_KEEP, svd_solver="auto", random_state=0)))

# choose model
if MODEL_TYPE == "rf":
    model = RandomForestRegressor(n_estimators=100, random_state=0, n_jobs=-1)
elif MODEL_TYPE == "ridge":
    model = Ridge(alpha=1.0, random_state=0)
else:
    raise ValueError("MODEL_TYPE must be 'rf' or 'ridge'")

steps.append(("model", model))
pipe = Pipeline(steps)
# Out:
# [2/7] Building pipeline (Scaler -> PCA -> Ridge)...

# %% [markdown]
# Set up the Test/Train split, run the fit no train, and evaluate on train and test.

# %%
# 3) Train/test split (80/20)
print("[3/7] Splitting data (80/20)...")
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=0
)
print(f"   -> Train: {X_train.shape}, Test: {X_test.shape}\n")

# 4) Fit on the training set
print("[4/7] Fitting pipeline on training data...")
pipe.fit(X_train, y_train)
print("   -> Fit complete.")
if USE_PCA:
    # Access the fitted PCA to report components retained
    pca = pipe.named_steps["pca"]
    print(f"   -> PCA retained {pca.n_components_} components "
          f"({pca.explained_variance_ratio_.sum():.3f} variance)\n")
else:
    print("   -> PCA disabled.\n")

# 5) Evaluate on train & test
print("[5/7] Evaluating holdout performance...")
def metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = float(np.sqrt(mean_squared_error(y_true, y_pred)))
    r2 = r2_score(y_true, y_pred)
    return mae, rmse, r2

y_pred_train = pipe.predict(X_train)
y_pred_test  = pipe.predict(X_test)

mae_tr, rmse_tr, r2_tr = metrics(y_train, y_pred_train)
mae_te, rmse_te, r2_te = metrics(y_test,  y_pred_test)

print("=== Holdout Performance (80/20 split) ===")
print(f"Train: MAE={mae_tr:.4f}, RMSE={rmse_tr:.4f}, R²={r2_tr:.4f}")
print(f"Test : MAE={mae_te:.4f}, RMSE={rmse_te:.4f}, R²={r2_te:.4f}\n")
# Out:
# [3/7] Splitting data (80/20)...
#    -> Train: (1830, 348), Test: (458, 348)
#
# [4/7] Fitting pipeline on training data...
#    -> Fit complete.
#    -> PCA retained 32 components (0.953 variance)
#
# [5/7] Evaluating holdout performance...
# === Holdout Performance (80/20 split) ===
# Train: MAE=0.4827, RMSE=0.6756, R²=0.4525
# Test : MAE=0.4898, RMSE=0.6959, R²=0.4386

# %% [markdown]
# Do cross validation to get good statistics on left out "test" data.

# %%
# 6) 5-fold cross-validation (uses the SAME pipeline to avoid leakage)
print("[6/7] Running 5-fold cross-validation...")
cv = KFold(n_splits=5, shuffle=True, random_state=0)
cv_results = cross_validate(
    pipe, X, y,
    cv=cv,
    scoring={
        "mae": "neg_mean_absolute_error",
        "rmse": "neg_root_mean_squared_error",
        "r2": "r2"
    },
    n_jobs=-1,
    return_train_score=False
)

cv_mae  = -cv_results["test_mae"]
cv_rmse = -cv_results["test_rmse"]
cv_r2   =  cv_results["test_r2"]

print("=== 5-Fold Cross-Validation (entire dataset) ===")
print(f"MAE : mean={cv_mae.mean():.4f} ± {cv_mae.std():.4f}")
print(f"RMSE: mean={cv_rmse.mean():.4f} ± {cv_rmse.std():.4f}")
print(f"R²  : mean={cv_r2.mean():.4f} ± {cv_r2.std():.4f}\n")
# Out:
# [6/7] Running 5-fold cross-validation...
# === 5-Fold Cross-Validation (entire dataset) ===
# MAE : mean=0.4953 ± 0.0147
# RMSE: mean=0.6938 ± 0.0174
# R²  : mean=0.4223 ± 0.0433

# %% [markdown]
# Now plot results as parity plots.

# %%
# 7) Parity plots for Train and Test (side-by-side, smaller)
print("[7/7] Generating parity plots...")

import matplotlib.pyplot as plt
import numpy as np

plot_tag = "PCA-ON" if USE_PCA else "PCA-OFF"

fig, axes = plt.subplots(1, 2, figsize=(8, 3.8))  # smaller plots side by side

for ax, (y_true, y_pred, title) in zip(
    axes,
    [
        (y_train, y_pred_train, f"Train [{plot_tag}]"),
        (y_test,  y_pred_test,  f"Test  [{plot_tag}]"),
    ],
):
    ax.scatter(y_true, y_pred, s=15, alpha=0.7, edgecolor="none")
    lo = min(np.min(y_true), np.min(y_pred))
    hi = max(np.max(y_true), np.max(y_pred))
    ax.plot([lo, hi], [lo, hi], linestyle="--", linewidth=1, color="black")
    ax.set_xlim(lo, hi)
    ax.set_ylim(lo, hi)
    ax.set_xlabel("True")
    ax.set_ylabel("Predicted")
    ax.set_title(title, fontsize=10)

plt.tight_layout()
plt.show()

print("\n✅ Workflow complete.")
# Out:
# [7/7] Generating parity plots...
# ✅ Workflow complete.

# %% [markdown]
# That is a complete fit and assessment with test data and cross-validation. To explore further, consider trying the following
# 1. Change MODEL_TYPE to "rf" for Random Forest. This is a more sophisticated ML method than ridge and gives significantly better results. However, it is slower (takes ~1min on my google colab CPU).
# 2. Try turning off PCA. This will then use the full feature set, which gives the best possible features but can take a long time with random forest (about 3m on my google colab CPU).
#
#
# Here were my final best statistics (but maybe you can beat them!)
#
# [5/7] Evaluating holdout performance...
#
# === Holdout Performance (80/20 split) ===
#
# Train: MAE=0.1045, RMSE=0.1721, R²=0.9645
#
# Test : MAE=0.2601, RMSE=0.4285, R²=0.7872
#
# [6/7] Running 5-fold cross-validation...
#
# === 5-Fold Cross-Validation (entire dataset) ===
#
# MAE : mean=0.2479 ± 0.0089
#
# RMSE: mean=0.4153 ± 0.0132
#
# R²  : mean=0.7929 ± 0.0173

# %% [markdown]
# THE END

# %% [markdown]
# # Backup
# The Following is backup in useful single cell format.

# %%
'''
# Code in one cell for easy updating.
# --- Random Forest regression with optional PCA reduction, 80/20 split + 5-fold CV ---

print("Starting RF workflow with optional PCA feature reduction...\n")

# Core sklearn imports
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge  # <-- added for optional linear model

# ======= PCA options =======
USE_PCA = True            # <- turn PCA on/off
PCA_VAR_KEEP = 0.95       # keep 95% variance (sklearn PCA allows float in (0,1])
# ===========================

# ======= Model option =======
MODEL_TYPE = "ridge"         # one of: "rf", "ridge"
# ===========================

# 1) Prepare data (assumes X_elem dataframe, y array-like)
print("[1/7] Preparing data...")
X = X_elem.copy()
y = df['Average voltage (V/ion)'].values.ravel()  # ensure 1D target

# Keep only numeric columns and drop rows with NaNs/Infs
X = X.select_dtypes(include=np.number)
mask = np.isfinite(X).all(axis=1) & np.isfinite(y)
X, y = X.loc[mask], y[mask]

print(f"   -> Data after cleaning: {X.shape[0]} samples, {X.shape[1]} features")
print("   -> Example feature cols:", list(X.columns[:5]), "\n")

# 2) Build the modeling pipeline: [Scaler] -> [PCA?] -> [Model]
model_name = "RF" if MODEL_TYPE == "rf" else "Ridge"
print("[2/7] Building pipeline (Scaler -> {} -> {})...".format("PCA" if USE_PCA else "No PCA", model_name))
steps = [("scaler", StandardScaler())]
if USE_PCA:
    steps.append(("pca", PCA(n_components=PCA_VAR_KEEP, svd_solver="auto", random_state=0)))

# choose model
if MODEL_TYPE == "rf":
    model = RandomForestRegressor(n_estimators=100, random_state=0, n_jobs=-1)
elif MODEL_TYPE == "ridge":
    model = Ridge(alpha=1.0, random_state=0)
else:
    raise ValueError("MODEL_TYPE must be 'rf' or 'ridge'")

steps.append(("model", model))
pipe = Pipeline(steps)

# 3) Train/test split (80/20)
print("[3/7] Splitting data (80/20)...")
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=0
)
print(f"   -> Train: {X_train.shape}, Test: {X_test.shape}\n")

# 4) Fit on the training set
print("[4/7] Fitting pipeline on training data...")
pipe.fit(X_train, y_train)
print("   -> Fit complete.")
if USE_PCA:
    # Access the fitted PCA to report components retained
    pca = pipe.named_steps["pca"]
    print(f"   -> PCA retained {pca.n_components_} components "
          f"({pca.explained_variance_ratio_.sum():.3f} variance)\n")
else:
    print("   -> PCA disabled.\n")

# 5) Evaluate on train & test
print("[5/7] Evaluating holdout performance...")
def metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = float(np.sqrt(mean_squared_error(y_true, y_pred)))
    r2 = r2_score(y_true, y_pred)
    return mae, rmse, r2

y_pred_train = pipe.predict(X_train)
y_pred_test  = pipe.predict(X_test)

mae_tr, rmse_tr, r2_tr = metrics(y_train, y_pred_train)
mae_te, rmse_te, r2_te = metrics(y_test,  y_pred_test)

print("=== Holdout Performance (80/20 split) ===")
print(f"Train: MAE={mae_tr:.4f}, RMSE={rmse_tr:.4f}, R²={r2_tr:.4f}")
print(f"Test : MAE={mae_te:.4f}, RMSE={rmse_te:.4f}, R²={r2_te:.4f}\n")

# 6) 5-fold cross-validation (uses the SAME pipeline to avoid leakage)
print("[6/7] Running 5-fold cross-validation...")
cv = KFold(n_splits=5, shuffle=True, random_state=0)
cv_results = cross_validate(
    pipe, X, y,
    cv=cv,
    scoring={
        "mae": "neg_mean_absolute_error",
        "rmse": "neg_root_mean_squared_error",
        "r2": "r2"
    },
    n_jobs=-1,
    return_train_score=False
)

cv_mae  = -cv_results["test_mae"]
cv_rmse = -cv_results["test_rmse"]
cv_r2   =  cv_results["test_r2"]

print("=== 5-Fold Cross-Validation (entire dataset) ===")
print(f"MAE : mean={cv_mae.mean():.4f} ± {cv_mae.std():.4f}")
print(f"RMSE: mean={cv_rmse.mean():.4f} ± {cv_rmse.std():.4f}")
print(f"R²  : mean={cv_r2.mean():.4f} ± {cv_r2.std():.4f}\n")

# 7) Parity plots for Train and Test (side-by-side, smaller)
print("[7/7] Generating parity plots...")

import matplotlib.pyplot as plt
import numpy as np

plot_tag = "PCA-ON" if USE_PCA else "PCA-OFF"

fig, axes = plt.subplots(1, 2, figsize=(8, 3.8))  # smaller plots side by side

for ax, (y_true, y_pred, title) in zip(
    axes,
    [
        (y_train, y_pred_train, f"Train [{plot_tag}]"),
        (y_test,  y_pred_test,  f"Test  [{plot_tag}]"),
    ],
):
    ax.scatter(y_true, y_pred, s=15, alpha=0.7, edgecolor="none")
    lo = min(np.min(y_true), np.min(y_pred))
    hi = max(np.max(y_true), np.max(y_pred))
    ax.plot([lo, hi], [lo, hi], linestyle="--", linewidth=1, color="black")
    ax.set_xlim(lo, hi)
    ax.set_ylim(lo, hi)
    ax.set_xlabel("True")
    ax.set_ylabel("Predicted")
    ax.set_title(title, fontsize=10)

plt.tight_layout()
plt.show()

print("\n✅ Workflow complete.")
'''
# Out:
# '\n# Code in one cell for easy updating.\n# --- Random Forest regression with optional PCA reduction, 80/20 split + 5-fold CV ---\n\nprint("Starting RF workflow with optional PCA feature reduction...\n")\n\n# Core sklearn imports\nfrom sklearn.ensemble import RandomForestRegressor\nfrom sklearn.model_selection import train_test_split, KFold, cross_validate\nfrom sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score\nfrom sklearn.pipeline import Pipeline\nfrom sklearn.preprocessing import StandardScaler\nfrom sklearn.decomposition import PCA\nfrom sklearn.linear_model import Ridge  # <-- added for optional linear model\n\n# ======= PCA options =======\nUSE_PCA = True            # <- turn PCA on/off\nPCA_VAR_KEEP = 0.95       # keep 95% variance (sklearn PCA allows float in (0,1])\n# ===========================\n\n# ======= Model option =======\nMODEL_TYPE = "ridge"         # one of: "rf", "ridge"\n# ===========================\n\n# 1) Prepare data (assumes X_elem dataframe, y array-like)\nprint("[1/7] Preparing data...")\nX = X_elem.copy()\ny = df[\'Average voltage (V/ion)\'].values.ravel()  # ensure 1D target\n\n# Keep only numeric columns and drop rows with NaNs/Infs\nX = X.select_dtypes(include=np.number)\nmask = np.isfinite(X).all(axis=1) & np.isfinite(y)\nX, y = X.loc[mask], y[mask]\n\nprint(f"   -> Data after cleaning: {X.shape[0]} samples, {X.shape[1]} features")\nprint("   -> Example feature cols:", list(X.columns[:5]), "\n")\n\n# 2) Build the modeling pipeline: [Scaler] -> [PCA?] -> [Model]\nmodel_name = "RF" if MODEL_TYPE == "rf" else "Ridge"\nprint("[2/7] Building pipeline (Scaler -> {} -> {})...".format("PCA" if USE_PCA else "No PCA", model_name))\nsteps = [("scaler", StandardScaler())]\nif USE_PCA:\n    steps.append(("pca", PCA(n_components=PCA_VAR_KEEP, svd_solver="auto", random_state=0)))\n\n# choose model\nif MODEL_TYPE == "rf":\n    model = RandomForestRegressor(n_estimators=100, random_state=0, n_jobs=-1)\nelif MODEL_TYPE == "ridge":\n    model = Ridge(alpha=1.0, random_state=0)\nelse:\n    raise ValueError("MODEL_TYPE must be \'rf\' or \'ridge\'")\n\nsteps.append(("model", model))\npipe = Pipeline(steps)\n\n# 3) Train/test split (80/20)\nprint("[3/7] Splitting data (80/20)...")\nX_train, X_test, y_train, y_test = train_test_split(\n    X, y, test_size=0.20, random_state=0\n)\nprint(f"   -> Train: {X_train.shape}, Test: {X_test.shape}\n")\n\n# 4) Fit on the training set\nprint("[4/7] Fitting pipeline on training data...")\npipe.fit(X_train, y_train)\nprint("   -> Fit complete.")\nif USE_PCA:\n    # Access the fitted PCA to report components retained\n    pca = pipe.named_steps["pca"]\n    print(f"   -> PCA retained {pca.n_components_} components "\n          f"({pca.explained_variance_ratio_.sum():.3f} variance)\n")\nelse:\n    print("   -> PCA disabled.\n")\n\n# 5) Evaluate on train & test\nprint("[5/7] Evaluating holdout performance...")\ndef metrics(y_true, y_pred):\n    mae = mean_absolute_error(y_true, y_pred)\n    rmse = float(np.sqrt(mean_squared_error(y_true, y_pred)))\n    r2 = r2_score(y_true, y_pred)\n    return mae, rmse, r2\n\ny_pred_train = pipe.predict(X_train)\ny_pred_test  = pipe.predict(X_test)\n\nmae_tr, rmse_tr, r2_tr = metrics(y_train, y_pred_train)\nmae_te, rmse_te, r2_te = metrics(y_test,  y_pred_test)\n\nprint("=== Holdout Performance (80/20 split) ===")\nprint(f"Train: MAE={mae_tr:.4f}, RMSE={rmse_tr:.4f}, R²={r2_tr:.4f}")\nprint(f"Test : MAE={mae_te:.4f}, RMSE={rmse_te:.4f}, R²={r2_te:.4f}\n")\n\n# 6) 5-fold cross-validation (uses the SAME pipeline to avoid leakage)\nprint("[6/7] Running 5-fold cross-validation...")\ncv = KFold(n_splits=5, shuffle=True, random_state=0)\ncv_results = cross_validate(\n    pipe, X, y,\n    cv=cv,\n    scoring={\n        "mae": "neg_mean_absolute_error",\n        "rmse": "neg_root_mean_squared_error",\n        "r2": "r2"\n    },\n    n_jobs=-1,\n    return_train_score=False\n)\n\ncv_mae  = -cv_results["test_mae"]\ncv_rmse = -cv_results[ ...
